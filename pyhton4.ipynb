# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %%
n = 500
categories = ['Food', 'Travel', 'Fashion', 'Fitness', 'Music', 'Culture', 'Family', 'Health']

# %%
data = {
    'Date': pd.date_range('2021-01-01', periods=n),
    'Category': [random.choice(categories) for _ in range(n)],
    'Likes': np.random.randint(0, 10000, size=n)
}

# %%
df = pd.DataFrame(data)
print(df.head())
print(df.info())
print(df.describe())
print(df['Category'].value_counts())
# Out:
#         Date Category  Likes
# 0 2021-01-01   Travel   9165
# 1 2021-01-02  Fitness   8359
# 2 2021-01-03   Family   7471
# 3 2021-01-04     Food   9442
# 4 2021-01-05   Health   8584
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      500 non-null    datetime64[ns]
#  1   Category  500 non-null    object
#  2   Likes     500 non-null    int32
# dtypes: datetime64[ns](1), int32(1), object(1)
# memory usage: 9.9+ KB
# None
#                       Date        Likes
# count                  500   500.000000
# mean   2021-09-07 12:00:00  5043.702000
# min    2021-01-01 00:00:00    49.000000
# 25%    2021-05-05 18:00:00  2484.500000
# 50%    2021-09-07 12:00:00  5027.000000
# 75%    2022-01-10 06:00:00  7585.750000
# max    2022-05-15 00:00:00  9997.000000
# std                    NaN  2898.486238
# Category
# Fitness    70
# Food       70
# Music      69
# Culture    68
# Family     62
# Health     59
# Fashion    59
# Travel     43
# Name: count, dtype: int64

# %%
df.dropna(inplace=True)
df.drop_duplicates(inplace=True)
df['Date'] = pd.to_datetime(df['Date'])
df['Likes'] = df['Likes'].astype(int)

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(df['Likes'], bins=30, kde=True)
plt.title('Distribution of Likes')
plt.xlabel('Likes')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.subplot(1, 2, 2)
sns.boxplot(x='Category', y='Likes', data=df)
plt.title('Likes by Category')
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'Travel'),
#   Text(1, 0, 'Fitness'),
#   Text(2, 0, 'Family'),
#   Text(3, 0, 'Food'),
#   Text(4, 0, 'Health'),
#   Text(5, 0, 'Music'),
#   Text(6, 0, 'Culture'),
#   Text(7, 0, 'Fashion')])

# %%
plt.tight_layout()
plt.show()

# %%
mean_likes = df['Likes'].mean()
print(f'Mean Likes: {mean_likes}')
mean_likes_by_category = df.groupby('Category')['Likes'].mean()
print(mean_likes_by_category)
# Out:
# Mean Likes: 5043.702
# Category
# Culture    5309.058824
# Family     5099.951613
# Fashion    5560.542373
# Fitness    4652.271429
# Food       4955.385714
# Health     4941.135593
# Music      5238.768116
# Travel     4442.511628
# Name: Likes, dtype: float64
